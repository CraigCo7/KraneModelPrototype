# %%
# Need to install this version as it is deprecated in the kernel

import sys
# !{sys.executable} -m pip install spacy
# !{sys.executable} -m pip install tensorflow
# !{sys.executable} -m spacy download en_core_web_sm
# !{sys.executable} -m pip install openai==0.28
# Out:
# Requirement already satisfied: spacy in /Users/craigco/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: tensorflow in /Users/craigco/anaconda3/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (4.25.0)
# Requirement already satisfied: setuptools in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 17.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Requirement already satisfied: openai==0.28 in /Users/craigco/anaconda3/lib/python3.11/site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /Users/craigco/anaconda3/lib/python3.11/site-packages (from openai==0.28) (4.65.0)
# Requirement already satisfied: aiohttp in /Users/craigco/anaconda3/lib/python3.11/site-packages (from openai==0.28) (3.8.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from requests>=2.20->openai==0.28) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/craigco/anaconda3/lib/python3.11/site-packages (from aiohttp->openai==0.28) (1.2.0)

# %%
import pandas as pd
import gensim.downloader as api

# Import the datasets

# schedDf = pd.read_csv('CE Input/Prototype Schedule Input.csv')
# bomDf = pd.read_csv('CE Input/Prototype Materials Input (Updated).csv')
# csv_out_path = "CE Output/Output-CEModelProcess (GlorifiedDataManipulation).csv"

schedDf = pd.read_csv('CE Input/Prototype 2 Schedule Input (Updated).csv')
bomDf = pd.read_csv('CE Input/Prototype 2 Materials Input (Updated).csv')
csv_out_path = "CE Output/Output-CEModelProcess Prototype 2(GlorifiedDataManipulation).csv"

# Import the word model
model = api.load("word2vec-google-news-300")

# %%
from torch import cosine_similarity
import torch
import numpy as np

def word2vec(model, word):
    return model[word.lower()]

def sentence2vec(value, model):
    sentence = value.split()

    # Initialize an empty vector to store the sentence vector
    sentence_vector = np.zeros(model.vector_size)

    # Counter to keep track of the number of words in the sentence
    word_count = 0

    # Calculate the sum of word vectors for the words in the sentence
    for word in sentence:
        if word.lower() in model:
            sentence_vector += model[word.lower()]
            word_count += 1

    # Check if there are words in the sentence that have embeddings
    if word_count > 0:
        # Calculate the average by dividing by the number of words
        sentence_vector /= word_count
    return sentence_vector

def cosineSimilarity(vector1, vector2):

    word_vector = torch.tensor(vector1).clone().detach().requires_grad_(True)
    sentence_vector = torch.tensor(vector2).clone().detach().requires_grad_(True)
    # Calculate cosine similarity between the sentence embeddings
    similarity = cosine_similarity(
        word_vector.unsqueeze(0), sentence_vector.unsqueeze(0))
    val = similarity[0].item()
    return val

# %%
# Feature Modelling
from itertools import product
from datetime import datetime

date_format = "%m/%d/%Y"

bomDf.dropna(subset=['Material BOM'], inplace=True)
schedDf.dropna(subset=['Activity Description'], inplace=True)

# Remove all whitespace
bomDf = bomDf.applymap(lambda x: x.strip() if isinstance(x, str) else x)
schedDf = schedDf.applymap(lambda x: x.strip() if isinstance(x, str) else x)


# startDate = datetime.strptime(row[2].strip(), date_format)
# endDate = datetime.strptime(row[3].strip(), date_format)
# ProcStepDuration = str(endDate-startDate).split(',')[0]


# Create SemanticWordVec Feature
schedDf['SemanticWordVec'] = schedDf['Activity Description'].apply(sentence2vec, args = (model,))

# Create Duration Feature
schedDf['Duration'] = schedDf.apply(lambda row: str(datetime.strptime(row['End Date'], date_format) - datetime.strptime(row['Start Date'], date_format)).split(',')[0], axis=1)

# %%
# PROCSTEP

threshold = 0.95

# Array of 2D data [activity description, wordvec]
selected_columns = schedDf[['Activity Description', 'SemanticWordVec']].values.tolist()
# print(selected_columns[0])

for i, row1 in enumerate(selected_columns):
    for j, row2 in enumerate(selected_columns[i+1:]):
        cosine_sim = cosineSimilarity(row1[1], row2[1])
        if cosine_sim > threshold:
            print(row1[0], row2[0], cosine_sim)
            row1.append(1)
            selected_columns.remove(row2)
            
for i in selected_columns:
    print(i[0])
# Out:
# Concrete curing - level 1 Concrete curing - level 2 0.9898076804939864
# Concrete curing - level 1 Concrete curing - level 3 0.985390126474945
# Concrete curing - level 1 Concrete curing - level 4 0.9843044084892488
# Concrete curing - level 1 Concrete curing - level 5 0.9837573827360437
# Dismantle forms - level 1 Dismantle forms - level 2 0.9894809188770273
# Dismantle forms - level 1 Dismantle forms - level 3 0.9848715673052031
# Dismantle forms - level 1 Dismantle forms - level 4 0.9837613847743365
# Dismantle forms - level 1 Dismantle forms - level 5 0.9831950341530544
# Install forms - level 1 Install forms - level 2 0.9889754317571655
# Install forms - level 1 Install forms - level 3 0.9841745992558064
# Install forms - level 1 Install forms - level 4 0.9830134004694275
# Install forms - level 1 Install forms - level 5 0.9824672857736959
# Install MEPs - level 1 Install MEPs - level 2 0.9838477204378506
# Install MEPs - level 1 Install MEPs - level 3 0.976944078271879
# Install MEPs - level 1 Install MEPs - level 4 0.9750988786329726
# Install MEPs - level 1 Install MEPs - level 5 0.9743241832095224
# Install rebar and embed items - level 1 Install rebar and embed items - level 2 0.9955789096705217
# Install rebar and embed items - level 1 Install rebar and embed items - level 3 0.9936773952343089
# Install rebar and embed items - level 1 Install rebar and embed items - level 4 0.9932177286920282
# Install rebar and embed items - level 1 Install rebar and embed items - level 5 0.9929985471583263
# Post pour inspection and sign-off - level 1 Post pour inspection and sign-off - level 2 0.9919951401733067
# Post pour inspection and sign-off - level 1 Post pour inspection and sign-off - level 3 0.9885041214592483
# Post pour inspection and sign-off - level 1 Post pour inspection and sign-off - level 4 0.9876639120433853
# Post pour inspection and sign-off - level 1 Post pour inspection and sign-off - level 5 0.9871986226024447
# Pour concrete - level 1 Pour concrete - level 2 0.9901316453316699
# Pour concrete - level 1 Pour concrete - level 3 0.9858184345589123
# Pour concrete - level 1 Pour concrete - level 4 0.984779757397285
# Pour concrete - level 1 Pour concrete - level 5 0.9841958576367846
# Pre pour inspection - level 1 Pre pour inspection - level 2 0.991880376890488
# Pre pour inspection - level 1 Pre pour inspection - level 3 0.9883392791795382
# Pre pour inspection - level 1 Pre pour inspection - level 4 0.9874908968359827
# Pre pour inspection - level 1 Pre pour inspection - level 5 0.9870215187650051
# Concrete curing - level 1
# Dismantle forms - level 1
# Install forms - level 1
# Install MEPs - level 1
# Install rebar and embed items - level 1
# Post pour inspection and sign-off - level 1
# Pour concrete - level 1
# Pre pour inspection - level 1

# %%
# PROCESSOUTPUT
# Try to use ML model?

import openai
import os
import ast

openai.api_key = "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"

activity_list = [i[0] for i in selected_columns]

def findProcessOutputOpenAi():
    prompt = "You will be given a list of sub tasks. Answer this question for each sub task: _ is a sub task you need to fulfil in order to complete which part of a building? Example: 'Install Tiles'. Output: 'Roof'. Answer in one word only, and make sure the keys are identical to the values in the input list. Return a python dictionary. Here is the list of sub tasks: " + \
        ', '.join(map(str, activity_list))
    response = openai.Completion.create(
        model="gpt-3.5-turbo-instruct",
        prompt=prompt,
        max_tokens=1000,
        temperature=0,
        best_of=1
    )
    # Convert ChatGPT Output to Dictionary.
    my_dict = ast.literal_eval(response['choices'][0]['text'].strip())
    return my_dict

# print(findProcessOutputOpenAi())
# Out:
# You will be given a list of sub tasks. Answer this question for each sub task: _ is a sub task you need to fulfil in order to complete which part of a building? Example: 'Install Tiles'. Output: 'Roof'. Answer in one word only, and make sure the keys are identical to the values in the input list. Return a python dictionary. Here is the list of sub tasks: Concrete curing - level 1, Dismantle forms - level 1, Install forms - level 1, Install MEPs - level 1, Install rebar and embed items - level 1, Post pour inspection and sign-off - level 1, Pour concrete - level 1, Pre pour inspection - level 1
# {
#   "id": "cmpl-8Mvzxvw5YtcKvUN5oKXTd9LCVhukv",
#   "object": "text_completion",
#   "created": 1700476853,
#   "model": "gpt-3.5-turbo-instruct",
#   "choices": [
#     {
#       "text": "\n\n{'Concrete curing': 'Foundation', 'Dismantle forms': 'Foundation', 'Install forms': 'Foundation', 'Install MEPs': 'Foundation', 'Install rebar and embed items': 'Foundation', 'Post pour inspection and sign-off': 'Foundation', 'Pour concrete': 'Foundation', 'Pre pour inspection': 'Foundation'}",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 151,
#     "completion_tokens": 70,
#     "total_tokens": 221
#   }
# }
# {'Concrete curing': 'Foundation', 'Dismantle forms': 'Foundation', 'Install forms': 'Foundation', 'Install MEPs': 'Foundation', 'Install rebar and embed items': 'Foundation', 'Post pour inspection and sign-off': 'Foundation', 'Pour concrete': 'Foundation', 'Pre pour inspection': 'Foundation'}

# %%
# PROCESS SUCCESSOR
# Try to use ML model?

def findProcessStepSuccessorOpenAi():
    prompt = "You will be given a list of sub tasks. These sub tasks are done sequentially, and your job is to determine which task precedes/succeeds the other. Answer in one word only, and make sure the keys are identical to the input list. Return a python dictionary. Here is the list of sub tasks: " + \
        ', '.join(map(str, activity_list))
    response = openai.Completion.create(
        model="gpt-3.5-turbo-instruct",
        prompt=prompt,
        max_tokens=1000,
        temperature=0,
        best_of=1
    )
#     return response
    my_dict = ast.literal_eval(response['choices'][0]['text'].strip())
    return my_dict

# print(findProcessStepSuccessorOpenAi())

# %%
# MATERIAL ASSIGNMENT

import copy

# Thinking: compare cosine_sim of each row to categories in scheduleDF. Assign each material to the category that is most similar.
categories_wordVec = [[inner_list[0], inner_list[1]] for inner_list in selected_columns]
categories_only = [inner_list[0] for inner_list in selected_columns]

# Key: activity, Value: Empty list
my_dict = {key: [] for key in categories_only}

materialAssignment = copy.deepcopy(my_dict)

material_list = bomDf['Material BOM'].values.tolist()

# FIRST = "You will be given a list of materials and a list of activities. Your job is to determine which material is required to perform which activity. Some activities don't require any materials and some activities require multiple materials. If you are unsure, assign a material to the activity with the highest probability. Return a python dictionary, and make sure the keys are identical to the input list. Here is the list of activities: " + \
#         ', '.join(map(str, activity_list)) + ". " + "Here is the list of materials: " + \
#         ', '.join(map(str, material_list))


# def findMaterialAssignmentOpenAi():
#     prompt = "Assign the following list of materials to the most likely activity it is associated with. Some activities don't require any materials and some activities require multiple materials. Return a python dictionary, and make sure the keys are identical to the input list. Here is the list of activities: " + \
#         ', '.join(map(str, activity_list)) + ". " + "Here is the list of materials: " + \
#         ', '.join(map(str, material_list))
#     response = openai.Completion.create(
#         model="gpt-3.5-turbo-instruct",
#         prompt=prompt,
#         max_tokens=2000,
#         temperature=0,
#         best_of=1
#     )
#     my_dict = ast.literal_eval(response['choices'][0]['text'].strip())
#     return my_dict

for index, row in bomDf.iterrows():
    highest = -1
    assignment = None
    activity_desc = row[0]
    wordVec1 = sentence2vec(row[0], model)
    for category in categories_wordVec:
        wordVec2 = category[1]
        cosine_sim = cosineSimilarity(wordVec1, wordVec2)
        if cosine_sim > highest:
            highest = cosine_sim
            assignment = category[0]
    materialAssignment[assignment].append(row[1])

# print(materialAssignment)
# materialAssignment Stores the Assignments from BOM to Schedule...

# %%
# BatchSize

non_empty_activities = {key: value for key, value in materialAssignment.items() if len(value) > 0}

batchSize = copy.deepcopy(my_dict)

# for i in non_empty_activities.values():
#     print(i)

# for i in non_empty_keys.keys():
#     print(i)
# print(non_empty_keys)

num_duplicates = {sublist[0]: len(sublist)-1 for sublist in selected_columns}

for key, value in non_empty_activities.items():
    for material in value:
        amount = int(bomDf.loc[bomDf['Material BOM'] == material]['Amount'].values)
        batchSize[key].append(amount/num_duplicates[key])

# print(batchSize)

# %%
# Duration

from datetime import datetime

date_format = "%m/%d/%Y"

duration = copy.deepcopy(my_dict)

for key in duration.keys():
    start = datetime.strptime(schedDf[schedDf['Activity Description'] == key]['Start Date'].values.tolist()[0], date_format)
    end = datetime.strptime(schedDf[schedDf['Activity Description'] == key]['End Date'].values.tolist()[0], date_format)
    duration[key] = str(end-start).split(',')[0]

# print(duration)

# %%
# Resource Assignment

resourceAssignment = copy.deepcopy(my_dict)

for key in duration.keys():
    resource = schedDf[schedDf['Activity Description'] == key]['Subcontractor'].values.tolist()[0]
    resourceAssignment[key] = resource
    
# print(resourceAssignment)

# %%
# Resource Quantity

resourceQuantity = {}


for subcontractor in schedDf['Subcontractor'].unique():
    filteredDf = schedDf[schedDf['Subcontractor'] == subcontractor]
    max_value = filteredDf['Manpower'].max()
    resourceQuantity[subcontractor] = max_value
    
# print(resourceQuantity)

# %%
# Output Configuration!!

import csv

output_data = [["ID", "ProcessOutput", "ProcStep", "ProcStepSuccessor", "ProcStepDuration",
                    "ProcMaterialAssignment", "ProcMaterialBatchSize", "ProcResourceAssignment", "ProcResourceQuantity"]]

processOutput = findProcessOutputOpenAi()
processSuccessor = findProcessStepSuccessorOpenAi()

def findProcessOutput(activity):
    return processOutput[activity.split(' - ')[0]]

def findProcStepSuccessor(activity):
    try:
        out = processSuccessor[activity]
        return out.split(' - ')[0]
    except KeyError:
        return []

def findProcStepDuration(activity):
    return duration[activity]

def findProcMaterialAssignment(activity):
    return materialAssignment[activity]

def findProcMaterialBatchSize(activity):
    return batchSize[activity]

def findProcResourceAssignment(activity):
    return resourceAssignment[activity]

def findProcResourceQuantity(activity):
    resAssignment = resourceAssignment[activity]
    return resourceQuantity[resAssignment]

data = [[i+1, findProcessOutput(item[0]), item[0].split(' - ')[0], findProcStepSuccessor(item[0]), findProcStepDuration(item[0]), findProcMaterialAssignment(item[0]), findProcMaterialBatchSize(item[0]), findProcResourceAssignment(item[0]), findProcResourceQuantity(item[0])] for i, item in enumerate(selected_columns)]

for row in data:
    output_data.append(row)

with open(csv_out_path, 'w', newline='') as output_file:
        csv_writer = csv.writer(output_file)

        # Write the processed data to the output file
        csv_writer.writerows(output_data)
# Out:
# You will be given a list of sub tasks. Answer this question for each sub task: _ is a sub task you need to fulfil in order to complete which part of a building? Example: 'Install Tiles'. Output: 'Roof'. Answer in one word only, and make sure the keys are identical to the values in the input list. Return a python dictionary. Here is the list of sub tasks: Concrete curing - level 1, Dismantle forms - level 1, Install forms - level 1, Install MEPs - level 1, Install rebar and embed items - level 1, Post pour inspection and sign-off - level 1, Pour concrete - level 1, Pre pour inspection - level 1
# {
#   "id": "cmpl-8Mvzz5TlqOgIx3NrpDaXJmMIBM1mD",
#   "object": "text_completion",
#   "created": 1700476855,
#   "model": "gpt-3.5-turbo-instruct",
#   "choices": [
#     {
#       "text": "\n\n{'Concrete curing': 'Foundation', 'Dismantle forms': 'Foundation', 'Install forms': 'Foundation', 'Install MEPs': 'Foundation', 'Install rebar and embed items': 'Foundation', 'Post pour inspection and sign-off': 'Foundation', 'Pour concrete': 'Foundation', 'Pre pour inspection': 'Foundation'}",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 151,
#     "completion_tokens": 70,
#     "total_tokens": 221
#   }
# }
